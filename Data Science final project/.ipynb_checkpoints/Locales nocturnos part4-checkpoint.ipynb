# %%
import pandas as pd

df_locales_nocturnos = pd.read_csv('opendatabcn_cultura_espais-de-musica-i-copes.csv', encoding='UTF-16')
#df_locales_nocturnos['addresses_neighborhood_name']
#df_locales_nocturnos['name']
#df_locales_nocturnos['secondary_filters_name']
# Out:
# 0               Cocteleries
# 1              Xampanyeries
# 2               Restaurants
# 3      Bars i pubs musicals
# 4               Cocteleries
#                ...
# 618             Discoteques
# 619             Cocteleries
# 620            Xampanyeries
# 621             Cocteleries
# 622            Xampanyeries
# Name: secondary_filters_name, Length: 623, dtype: object

# %%
df_numero_locales_nocturnos_por_barrio = df_locales_nocturnos.groupby('addresses_neighborhood_name').size().reset_index(name='Numero_de_Centros_Nocturnos')
df_numero_locales_nocturnos_por_barrio
# Out:
#               addresses_neighborhood_name  Numero_de_Centros_Nocturnos
# 0                                   Horta                            4
# 1                                   Navas                            4
# 2                               Pedralbes                            1
# 3                             Sant Andreu                            3
# 4                             Sant Antoni                           15
# 5                  Sant Gervasi - Galvany                           38
# 6              Sant Gervasi - la Bonanova                            8
# 7   Sant Pere, Santa Caterina i la Ribera                           59
# 8                                   Sants                           10
# 9                                  Sarrià                            5
# 10                         el Barri Gòtic                           52
# 11     el Camp d'en Grassot i Gràcia Nova                            2
# 12               el Congrés i els Indians                            3
# 13                          el Fort Pienc                            9
# 14                            el Guinardó                            1
# 15      el Parc i la Llacuna del Poblenou                           10
# 16                           el Poble-sec                           24
# 17                            el Poblenou                            6
# 18                   el Putxet i el Farró                            2
# 19                               el Raval                           69
# 20        l'Antiga Esquerra de l'Eixample                           88
# 21                         la Barceloneta                           28
# 22                 la Dreta de l'Eixample                           79
# 23             la Maternitat i Sant Ramon                            7
# 24         la Nova Esquerra de l'Eixample                           17
# 25                     la Sagrada Família                           10
# 26          la Vila Olímpica del Poblenou                            7
# 27                      la Vila de Gràcia                           53
# 28                              les Corts                            9

# %%
import pandas as pd

#df_main = pd.read_csv('2020_est_salut_publica_fec_mares_15_19a.csv')
df_main = pd.read_csv('2020_atles_renda_mitjana.csv')

df_main.head(10)
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  Seccio_Censal  \
# 0  2020               1  Ciutat Vella           1  el Raval              1
# 1  2020               1  Ciutat Vella           1  el Raval              2
# 2  2020               1  Ciutat Vella           1  el Raval              3
# 3  2020               1  Ciutat Vella           1  el Raval              4
# 4  2020               1  Ciutat Vella           1  el Raval              5
# 5  2020               1  Ciutat Vella           1  el Raval              6
# 6  2020               1  Ciutat Vella           1  el Raval              7
# 7  2020               1  Ciutat Vella           1  el Raval              8
# 8  2020               1  Ciutat Vella           1  el Raval              9
# 9  2020               1  Ciutat Vella           1  el Raval             10
#
#    Mitjana_Renda_€
# 0            15672
# 1            12175
# 2            12718
# 3            14945
# 4            13268
# 5            14226
# ...

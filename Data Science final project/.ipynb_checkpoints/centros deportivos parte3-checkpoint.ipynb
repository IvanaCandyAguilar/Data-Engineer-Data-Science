# %%
import chardet

# Ruta y nombre del archivo
file_path = 'opendatabcn_esports_esports-individuals.csv'

# Leer los primeros 1000 bytes del archivo
with open(file_path, 'rb') as f:
    raw_data = f.read(1000)

# Detectar la codificación
result = chardet.detect(raw_data)
encoding = result['encoding']

# Imprimir la codificación detectada
print(f"La codificación del archivo es: {encoding}")
# Out:
# La codificación del archivo es: UTF-16

# %%
import pandas as pd

#df_main = pd.read_csv('2020_est_salut_publica_fec_mares_15_19a.csv')
df_main = pd.read_csv('opendatabcn_esports_esports-individuals.csv', encoding='UTF-16')

df_main.head(10)
# Out:
#     register_id                                           name  \
# 0  ﻿99400367239                       Club Mugendo *Alfons XII
# 1  ﻿99400367239                       Club Mugendo *Alfons XII
# 2  ﻿99400367239                       Club Mugendo *Alfons XII
# 3  ﻿99400327666  Gimnàs Holmes Place Can Dragó *Som Multiespai
# 4  ﻿99400327666  Gimnàs Holmes Place Can Dragó *Som Multiespai
# 5  ﻿99400327666  Gimnàs Holmes Place Can Dragó *Som Multiespai
# 6  ﻿99400327666  Gimnàs Holmes Place Can Dragó *Som Multiespai
# 7  ﻿93049122324                              Pistes de Petanca
# 8  ﻿93049122324                              Pistes de Petanca
# 9  ﻿96318122248                      Piscina Esportiva Coberta
#
#    institution_id                            institution_name  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# ...

# %%
df_numero_centro_deportivos_por_barrio = df_main.groupby('addresses_neighborhood_name').size().reset_index(name='Numero_de_Centros_Deportivos')
print(df_numero_centro_deportivos_por_barrio)
# Out:
#       addresses_neighborhood_name  Numero_de_Centros_Deportivos
# 0                   Baró de Viver                            11
# 1                    Camps Blancs                             2
# 2                        Can Baró                            19
# 3                       Canyelles                            27
# 4                Ciutat Meridiana                            27
# ..                            ...                           ...
# 69  la Vila Olímpica del Poblenou                            47
# 70              la Vila de Gràcia                           115
# 71                      les Corts                           117
# 72                   les Roquetes                            16
# 73                les Tres Torres                            20
#
# [74 rows x 2 columns]
